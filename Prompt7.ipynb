# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,100) #Fills x with 100 vallues between 0 and 1
def ex(x): #defins ex as e^x
    return np.exp(x)

# %%
y = ex(x) #sets y to the funtions of ex
plt.plot(x,y) #plots x vs y

plt.xlabel("Time [milliseconds]")
plt.xlabel("Awesomeness")
plt.savefig('prompt7.pdf',bbox_inches='tight',dpi=600)
